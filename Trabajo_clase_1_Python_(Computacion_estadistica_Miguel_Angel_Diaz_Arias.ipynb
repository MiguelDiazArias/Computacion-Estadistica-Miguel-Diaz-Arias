# %% [markdown]
# 1. Cargar un archivo de excel (con una ruta permanente en drive) (apoyarse en el modulo pandas)

# %%
import pandas as pd
pd.read_excel ('/content/drive/MyDrive/DISEÑO DE EXPERIMENTOS (TALLERES)/Taller VI Desing of experiments.xlsx')
# Out:
#     Unnamed: 0    Unnamed: 1   Unnamed: 2   Unnamed: 3   Unnamed: 4  \
# 0          NaN           NaN          NaN          NaN          NaN
# 1          NaN           NaN          NaN          NaN    Herbicida
# 2          NaN   Insecticida          0.0          0.5          1.0
# 3          NaN           0.0        122.0         72.5         52.0
# 4          NaN           NaN        121.0         70.2         51.4
# 5          NaN          20.0        82.75        84.75         71.5
# 6          NaN           NaN        81.45         81.6        70.41
# 7          NaN          40.0        64.75        68.75         79.5
# 8          NaN           NaN        62.41        62.54         78.8
# 9          NaN          60.0         68.0         70.0        68.75
# 10         NaN           NaN         67.0         71.4         64.3
# 11         NaN          80.0         57.5        60.75         63.0
# 12         NaN           NaN         53.4        61.42         62.0
# ...

# %% [markdown]
# 2. Colocar una imagen desde internet

# %% [markdown]
# ![](https://img.freepik.com/vector-gratis/clipart-dibujos-animados-ilustracion-vector-maiz-dorado_295192-50.jpg)

# %% [markdown]
# 3. Escribir una matrix 4x4 (en latex)

# %% [markdown]
# \begin{bmatrix}
# 1 &2  &3  &4 \\
#  x_1&x_2  &y_1  &y_2 \\
#  4&3  &2  &1 \\
#  x_2&x_1  &y_2  &y_1
# \end{bmatrix}

# %% [markdown]
# 4. Crear una tabla en latex

# %% [markdown]
# \begin{array}{|l|l|}
#     \hline
#         Empleado & Salario (COP) \\ \hline
#         Juan & 1'800.000 \\ \hline
#         Ernesto & 2'500.000 \\ \hline
#     \end{array}

# %% [markdown]
# 5. Copiar una ecuacion estadistica (en latex)

# %% [markdown]
# $$\bar{x}=\frac{\sum_{i=1}^{n}x_i}{n}$$
